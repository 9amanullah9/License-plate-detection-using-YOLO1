# %%
import zipfile
path = zipfile.ZipFile('/content/License Plate Recognition.v6i.yolov11.zip')

# %%
path.extractall()

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
pre_model =YOLO('yolo11n.pt')

# %%
pre_model.train(data ="/content/data.yaml", epochs =15 )
# Out:
# Ultralytics 8.3.243 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
pre_model.save('best.pt')

# %%
model_save = YOLO('/content/best.pt')

# %%
from IPython.display import Image
Image('/content/test/images/2eff96b0-5234-11e9-9eaf-881ce4aedc87_jpeg_jpg.rf.9296d723c27141517658c376a1747a7d.jpg')

# %%
pred =model_save.predict('/content/test/images/2eff96b0-5234-11e9-9eaf-881ce4aedc87_jpeg_jpg.rf.9296d723c27141517658c376a1747a7d.jpg')
# Out:
# image 1/1 /content/test/images/2eff96b0-5234-11e9-9eaf-881ce4aedc87_jpeg_jpg.rf.9296d723c27141517658c376a1747a7d.jpg: 640x640 1 License-Plate, 11.6ms
# Speed: 3.3ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
pred[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
model_save.predict("/content/WhatsApp Video 2025-12-30 at 5.26.57 PM.mp4" , save = True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/635) /content/WhatsApp Video 2025-12-30 at 5.26.57 PM.mp4: 384x640 2 License-Plates, 50.5ms
# video 1/1 (frame 2/635) /content/WhatsApp Video 2025-12-30 at 5.26.57 PM.mp4: 384x640 2 License-Plates, 8.3ms
# video 1/1 (frame 3/635) /content/WhatsApp Video 2025-12-30 at 5.26.57 PM.mp4: 384x640 2 License-Plates, 9.0ms
# ...

# %%
from IPython .display import Image
Image("/content/runs/detect/train/confusion_matrix.png")
